# %%
import matplotlib.pyplot as plt
import seaborn as sbn
import json
import os
import sys
import pandas as pd
import pickle

root_path = os.environ['FCLA_ROOT']
data_path = os.environ['DATA_PATH']
sys.path.append(os.path.join(root_path,'scripts'))

from mergeResults import *

# %%
load_results(os.path.join(data_path, "solutions", "geometric", "gurobi"), os.path.join(data_path,'geometric'))
# Out:
#    facility_capacity            id  number of facilities  objective   runtime  \
# 0                2.0  1.487948e+21                   2.0        0.0  0.004547
# 1                2.0  1.487948e+21                   2.0        0.0  0.005200
# 2                2.0  1.487948e+21                   7.0      544.0  0.017435
# 3                2.0  1.487948e+21                   2.0        0.0  0.000087
# 4                2.0  1.487948e+21                   7.0      521.0  0.014643
# 5                2.0  1.487948e+21                  12.0     1199.0  0.040502
# 6                2.0  1.487948e+21                   2.0        0.0  0.001577
# 7                2.0  1.487948e+21                   7.0      365.0  0.018963
# 8                2.0  1.487948e+21                  12.0      842.0  0.114345
# 9                2.0  1.487948e+21                  17.0     1101.0  0.373526
#
#    avg_clustering  avg_degree    avg_dist  ecount  max_degree  \
# 0        0.806825    6.200000  133.860215    31.0         9.0
# 1        0.758326   10.300000  101.718447   103.0        16.0
# 2        0.758326   10.300000  101.718447   103.0        16.0
# 3        0.712664    9.466667   84.708920   142.0        16.0
# 4        0.712664    9.466667   84.708920   142.0        16.0
# 5        0.712664    9.466667   84.708920   142.0        16.0
# 6        0.714682    9.350000   78.037433   187.0        16.0
# 7        0.714682    9.350000   78.037433   187.0        16.0
# 8        0.714682    9.350000   78.037433   187.0        16.0
# 9        0.714682    9.350000   78.037433   187.0        16.0
#
#         ...         network_diam  source_avg_clust  source_avg_degree  \
# 0       ...                925.0          0.611111           9.000000
# 1       ...               1010.0          0.712121          12.000000
# 2       ...               1010.0          0.760093          10.363636
# 3       ...               1294.0          0.833333           4.000000
# 4       ...               1294.0          0.704214          10.545455
# 5       ...               1294.0          0.715339           9.190476
# 6       ...               1322.0          0.500000           8.000000
# 7       ...               1322.0          0.786171           8.545455
# 8       ...               1322.0          0.758072           8.809524
# 9       ...               1322.0          0.744357           9.354839
#
#    source_avg_eccentricity  source_num  std_degree      std_dist  vcount  \
# 0               526.000000         1.0    2.760000  40306.292288    10.0
# 1               769.000000         1.0   11.710000  20510.875420    20.0
# 2               812.727273        11.0   11.710000  20510.875420    20.0
# 3              1046.000000         1.0   15.582222  12827.952831    30.0
# 4               953.000000        11.0   15.582222  12827.952831    30.0
# 5               972.523810        21.0   15.582222  12827.952831    30.0
# 6               946.000000         1.0   12.977500   9301.169722    40.0
# 7              1044.454545        11.0   12.977500   9301.169722    40.0
# 8              1047.714286        21.0   12.977500   9301.169722    40.0
# 9              1026.387097        31.0   12.977500   9301.169722    40.0
#
#    source_avg_dist  source_std_dist
# 0              NaN              NaN
# 1              NaN              NaN
# 2       469.945455     52496.124298
# 3              NaN              NaN
# 4       476.509091     56426.249917
# 5       527.457143     64756.086259
# 6              NaN              NaN
# 7       616.763636     86086.435041
# 8       592.180952     77798.633923
# 9       554.483871     73706.155116
#
# [10 rows x 23 columns]

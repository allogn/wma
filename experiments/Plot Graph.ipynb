# %%
import networkx as nx
# Out:
# ------------------------------------------------------------------------
# ImportError                            Traceback (most recent call last)
# <ipython-input-1-6002206e7c09> in <module>()
# ----> 1 import networkx as nx
#
# ImportError: No module named 'networkx'

# %%
G = nx.read_edgelist("./clustered/d_n1000-m100-cl5-k30-c10", delimiter=',', nodetype=str, data=(('weight',int),))

# %%
G

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(15,15))
nx.draw(G,node_size=10, with_labels = True)

# %%
nx.is_connected(G)
# Out:
# True

# %%
len(G)
# Out:
# 105

# %%
# plot as coords
import pandas as pd

# %%
data = pd.read_csv("graph.csv", header=None)
plt.figure(figsize=(10,10),dpi=150)
plt.axis('off')
plt.scatter(data[0],data[1])
